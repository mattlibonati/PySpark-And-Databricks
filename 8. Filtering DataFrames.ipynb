# %% [markdown]
# # Overview

# %% [markdown]
# Often datasets contain more information than is required for the immidate analysis. Filtering is used to limit records within datasets based on specified paramters.

# %%
import pyspark.sql.functions as f
from pyspark.sql.types import FloatType

# %%
sdf = spark.createDataFrame(
[
  ('Robin',  'Science', 95),
  ('Nathan', 'Science', 78),
  ('Anna',   'Science', 88),
  ('Sonia',  'Science', 87),
  ('Robin' , 'English', 95),
  ('Nathan', 'English', 80),
  ('Anna'  , 'English', 87),
  ('Sonia' , 'English', 91)
],
  ['student_name', 'subject_name', 'subject_score']
)

display(sdf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>student_name</th><th>subject_name</th><th>subject_score</th></tr></thead><tbody><tr><td>Robin</td><td>Science</td><td>95</td></tr><tr><td>Nathan</td><td>Science</td><td>78</td></tr><tr><td>Anna</td><td>Science</td><td>88</td></tr><tr><td>Sonia</td><td>Science</td><td>87</td></tr><tr><td>Robin</td><td>English</td><td>95</td></tr><tr><td>Nathan</td><td>English</td><td>80</td></tr><tr><td>Anna</td><td>English</td><td>87</td></tr><tr><td>Sonia</td><td>English</td><td>91</td></tr></tbody></table></div>

# %% [markdown]
# # Filtering Spark DataFrames

# %% [markdown]
# Filters are performed using the .where() or .filter functions. Note: when the .where function is used, you muse specify the column literal:

# %% [markdown]
# Using the .where() function:

# %%
# using pyspark.sql.functions .col() function 
sdf.where(f.col('subject_score') > 90).show() #<-- f.col() required 

# using column index
sdf.where(sdf.subject_score > 90)show()
# Out:
# +------------+------------+-------------+
# |student_name|subject_name|subject_score|
# +------------+------------+-------------+
# |       Robin|     Science|           95|
# |       Robin|     English|           95|
# |       Sonia|     English|           91|
# +------------+------------+-------------+
#
# +------------+------------+-------------+
# |student_name|subject_name|subject_score|
# +------------+------------+-------------+
# |       Robin|     Science|           95|
# |       Robin|     English|           95|
# |       Sonia|     English|           91|
# +------------+------------+-------------+

# %% [markdown]
# Alternatively, the .filter() function:

# %%
# using pyspark.sql.functions .col() function 
sdf.filter(f.col('subject_score') > 90).show() #<-- f.col() required 

# using column index
sdf.filter(sdf.subject_score > 90).show()
# Out:
# +------------+------------+-------------+
# |student_name|subject_name|subject_score|
# +------------+------------+-------------+
# |       Robin|     Science|           95|
# |       Robin|     English|           95|
# |       Sonia|     English|           91|
# +------------+------------+-------------+
#
# +------------+------------+-------------+
# |student_name|subject_name|subject_score|
# +------------+------------+-------------+
# |       Robin|     Science|           95|
# |       Robin|     English|           95|
# |       Sonia|     English|           91|
# +------------+------------+-------------+

# %% [markdown]
# The .like() function enables the filter to search for strings contaning specified stings:

# %%
sdf.filter(f.col("subject_name").like("%gli%")).show()
# Out:
# +------------+------------+-------------+
# |student_name|subject_name|subject_score|
# +------------+------------+-------------+
# |       Robin|     English|           95|
# |      Nathan|     English|           80|
# |        Anna|     English|           87|
# |       Sonia|     English|           91|
# +------------+------------+-------------+

# %% [markdown]
# The .isin() function enables filtering based on a specified list:

# %%
list_of_values = ['Sonia','Robin']

sdf.filter(f.col("student_name").isin(list_of_values)).show()

# using a "~" prior to the column literal will result in all records not in the list
sdf.filter(~f.col("student_name").isin(list_of_values)).show()
# Out:
# +------------+------------+-------------+
# |student_name|subject_name|subject_score|
# +------------+------------+-------------+
# |       Robin|     Science|           95|
# |       Sonia|     Science|           87|
# |       Robin|     English|           95|
# |       Sonia|     English|           91|
# +------------+------------+-------------+
#
# +------------+------------+-------------+
# |student_name|subject_name|subject_score|
# +------------+------------+-------------+
# |      Nathan|     Science|           78|
# |        Anna|     Science|           88|
# |      Nathan|     English|           80|
# |        Anna|     English|           87|
# +------------+------------+-------------+

# %% [markdown]
# Scripting for filtering based on Nulls can be found here: https://github.com/mattlibonati/PySpark-And-Databricks/blob/main/6.%20Handling%20Null%20Values.ipynb
